# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0,'../dataHandling')
import data_utilities as du

# %%
savepath = '../../resources/parameters/task_up_combinedweight/'
data = np.load(savepath+'estimatedparams2.npy')
data.shape
# Out:
# (6, 28, 100)

# %%
plt.plot(data[:,21,:].transpose())
plt.show()

# %%
filepath = '../../resources/training_data/task_up_combinedweight/'
list_datasets, dataset = du.combine(task_dir=filepath, n=0)
for dataset in list_datasets:
    plt.plot(dataset[:,2])
plt.show()
